# %% [markdown]
# # Wanderung zum Cahlet am Horizont

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Bergstation Gastlosen |
# | Ziel | Bergstation Gastlosen |
# | Strecke | 8.4 km |
# | Aufstieg | 630 m |
# | Abstieg | 595 m |
# | Marschzeit | 3 h 20 |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [46.609751, 7.174577]
cener_swiss_grid = [2579770.34, 1162089.14]
path = "250531_chalet.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Chalet")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](../../../images/250531_map_output.png)
# :::

# %%
profile(path)

# %% [markdown]
# Die Karte auf der Website von
# [swisstopo.ch](https://map.geo.admin.ch/#/map?lang=de&center=2579770.34,1162089.14&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum_illustriert/refs/heads/main/files/2025/250531_chalet/250531_chalet.gpx)
# oder in der
# [Mobile App](https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvcmVmcy9oZWFkcy9tYWluL2ZpbGVzLzIwMjUvMjUwNTMxX2NoYWxldC8yNTA1MzFfY2hhbGV0LmdweA==)
# von swisstopo öffnen.

# %%
generate_qr_code_for_url("https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvcmVmcy9oZWFkcy9tYWluL2ZpbGVzLzIwMjUvMjUwNTMxX2NoYWxldC8yNTA1MzFfY2hhbGV0LmdweA==")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# | Swisstopo.ch | Mobile App |
# | --- | --- |
# | ![](../../../images/250531_qr_tag.png){width=3cm height=3cm} | ![](../../../images/250531_app_qr_tag.png){width=3cm height=3cm} |
# :::

# %% [markdown]
# ::: {.content-visible when-format="html"}
#
# ## Bilder

# %% [markdown]
# :::
