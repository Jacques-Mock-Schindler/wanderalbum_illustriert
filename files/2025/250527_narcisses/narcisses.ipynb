# %% [markdown]
# # La Naige du Mai

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Châtel-St-Denis |
# | Ziel | Fayaux |
# | Strecke | 10.2 km |
# | Aufstieg | 730 m |
# | Abstieg | 570 m |
# | Marschzeit | 3 h 45 |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [46.498584, 6.910743]
cener_swiss_grid = [2559474.93, 1149833.73]
path = "250527_narcisses.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Sentier des Narcisses")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](../../../images/250527_map_output.png)
# :::

# %%
profile(path)

# %% [markdown]
# Die Karte auf der Website von
# [swisstopo.ch](https://map.geo.admin.ch/#/map?lang=de&center=2559474.93,1149833.73&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum_illustriert/refs/heads/main/files/2025/250527_narcisses/250527_narcisses.gpx)
# oder in der
# [Mobile App](https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvcmVmcy9oZWFkcy9tYWluL2ZpbGVzLzIwMjUvMjUwNTI3X25hcmNpc3Nlcy8yNTA1MjdfbmFyY2lzc2VzLmdweA==)
# von swisstopo öffnen.

# %%
generate_qr_code_for_url("https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvcmVmcy9oZWFkcy9tYWluL2ZpbGVzLzIwMjUvMjUwNTI3X25hcmNpc3Nlcy8yNTA1MjdfbmFyY2lzc2VzLmdweA==")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# | Swisstopo.ch | Mobile App |
# | --- | --- |
# | ![](../../../images/250527_qr_tag.png){width=3cm height=3cm} | ![](../../../images/250527_app_qr_tag.png){width=3cm height=3cm} |
# :::

# %% [markdown]
# ::: {.content-visible when-format="html"}
#
# ## Bilder

# %% [markdown]
# ![Die (neue) Bahnhofüberbauung in Châtel-St-Denis ist ein krasser Ortsplanerischer Kraftakt.](../../../images/250527_chatel-st-denis.jpg)

# %% [markdown]
# ![Eine Treppe im Wald oberhalb des Pont de Fégire. Erstaunlicherweise
# ist der Weg auf der Karte nicht als Wanderweg ausgezeichnet.](../../../images/250527_treppe.jpg)

# %% [markdown]
# ![Noch keine Narcissen aber immerhin eine erste Blumenwiese.](../../../images/250527_blumenwiese.jpg)

# %% [markdown]
# ![Wald-Storchenschnabel.](../../../images/250527_wald_strochenschnabel.jpg)

# %% [markdown]
# ![Die erste Stern-Narzisse auf einer...](../../../images/250527_stern_narzisse.jpg)

# %% [markdown]
# ![...Wiese voller Narzissen.](../../../images/250527_narzissen_wiese.jpg)

# %% [markdown]
# ![Ausblick über den District Veveyse.](../../../images/250527_veveyse.jpg)

# %% [markdown]
# []{#pair}![ohne Worte](../../../images/250527_narcisses_en_pair.jpg)

# %% [markdown]
# ![Eine Wiese voller Narzissen mit dem Dent de Lys im Hintergrund (bei La
# Châ).](../../../images/250527_dent_de_lys.jpg)

# %% [markdown]
# ![Le Tour d'Aï von les Pléyades aus gesehen.](../../../images/250527_tour_dai.jpg)

# %% [markdown]
# ![Das beste am Restaurant auf les Pléyades: Die Aussicht auf den Lac Léman.](../../../images/250527_lac_leman.jpg)

# %% [markdown]
# ![Ein Schlangen-Knöterich zum Schluss der Narzissenwanderung.](../../../images/250527_schlangen_knoeterich.jpg)

# %% [markdown]
# :::
