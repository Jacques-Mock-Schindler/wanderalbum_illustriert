# %% [markdown]
# # BLS Südrampe (Hohtenn - Eggerberg)

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Hohtenn |
# | Ziel | Eggerberg |
# | Strecke | 15.8 km |
# | Aufstieg | 925 m |
# | Abstieg | 1'100 m |
# | Marschzeit | 6 h |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [46.317118, 7.825553]
cener_swiss_grid = [2629801.57, 1129597.33]
path = "../../../files/2025/250803_suedrampe/250803_suedrampe.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Wanderung entlang der BLS Südrampe")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](map_output.png)
# :::

# %%
profile(path)

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](elevation_profile.png)
# :::

# %% [markdown]
# [Die Karte auf der Website von swisstopo.ch
# öffnen.](https://map.geo.admin.ch/#/map?lang=de&center=2629801.57,1129597.33&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum/main/files/2025/250803_suedrampe/250803_suedrampe.gpx)

# %%
generate_qr_code_for_url("https://map.geo.admin.ch/#/map?lang=de&center=2629801.57,1129597.33&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum/main/files/2025/250803_suedrampe/250803_suedrampe.gpx")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](qr_tag.png){width=3cm height=3cm}
# :::

# %% [markdown]
# ## Bilder

# %% [markdown]
# ![Ausblick vom Bahnhof Hohtenn entlang der Talflanke mit der Südrampe.](start.jpg)

# %% [markdown]
# ![Der erste Vidadukt nach Hohtenn in Richtung Brig.](viadukt.jpg)

# %% [markdown]
# ![Aussicht auf das vom Jolibach geformte Relief. Aufgenommen vom
# Picknick-Platz bei Punkt 1013.](jolibachschlucht.jpg)

# %% [markdown]
# ![Schöpfe (Wasserfassung) am Jolibach für die "Grossa" Suone.](schoepfe.jpg)

# %% [markdown]
# ![Beginn der "Grossa" Suone.](grossa.jpg)

# %% [markdown]
# ![Blick auf die Rarner Burgkirche. Neben dieser Kirche ist Rainer Maria
# Rilke begraben.](burgkirche.jpg)

# %% [markdown]
# ![Blick zurück Rohnetal abwärts. In der Bildmitte erkennt man den
# Westhang des Illgrabens.](illgraben.jpg)

# %% [markdown]
# ![Das erste Fusgängertunnel auf dem Trassee der ehemaligen Baubahn.](fussgaengertunnel.jpg)

# %% [markdown]
# ![Die andere Seite des Tunnels.](tunnel2.jpg)

# %% [markdown]
# ![Dass der Wanderweg auf dem Trassee der ehemaligen Baubahn verläuft,
# ist hier gut zu erkennen.](trassee.jpg)

# %% [markdown]
# ![Der Bietschbachviadukt.](bietschbachviadukt.jpg)

# %% [markdown]
# ![Wanderweg über den Bietschbachviadukt](bietschbachviadukt_wanderweg.jpg)

# %% [markdown]
# ![Der Wanderweg über den Bietschbachviadukt Südrampe aufwärts.](bietschbachviadukt_suedrampe_aufwaerts.jpg)

# %% [markdown]
# ![ohne Kommentar](herz.jpg)

# %% [markdown]
# ![ohne Kommentar](baum_auf_fels.jpg)

# %% [markdown]
# ![Wanderweg entlang der "Manera" Suone](manera.jpg)

# %% [markdown]
# ![Die "Manera" Suone in traditionellem Holzkanal.](manera_holzkanal.jpg)

# %% [markdown]
# ![Ausserberg](ausserberg.jpg)

# %% [markdown]
# ![Der Wanderweg bei Bärubrächa](baerubraecha.jpg)
