# %% [markdown]
# # Appenzell - Trogen

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Appenzell |
# | Ziel | Trogen |
# | Strecke | 13.7 km |
# | Aufstieg | 715 m |
# | Abstieg | 600 m |
# | Marschzeit | 4 h 15 |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [47.369822, 9.430254]
cener_swiss_grid = [2750416.08, 1248462.41]
path = "../../../files/2025/250719_appenzell/250719_appenzell.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Appenzell")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](map_output.png)
# :::

# %%
profile(path)

# %% [markdown]
# <div style="margin-bottom: 5mm;"></div>
#
# ![](elevation_profile.png)

# %% [markdown]
# [Die Karte auf der Website von swisstopo.ch
# öffnen.](https://map.geo.admin.ch/#/map?lang=de&center=2750416.08,1248462.41&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum/main/files/2025/250719_appenzell/250719_appenzell.gpx)

# %%
generate_qr_code_for_url("https://map.geo.admin.ch/#/map?lang=de&center=2750416.08,1248462.41&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum/main/files/2025/250719_appenzell/250719_appenzell.gpx")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](qr_tag.png){width=3cm height=3cm}
# :::

# %% [markdown]
# ## Bilder

# %% [markdown]
# ![Panorama von oberhalb Appenzell](panorama.jpg)

# %% [markdown]
# ![Kappelle Maria Hilf (Acker-Kapelle Hinterlehn)](kapelle.jpg)

# %% [markdown]
# ![Aussicht von der Hohen Buche Richtung Bodensee](bodensee.jpg)

# %% [markdown]
# ![Aussicht von der Hohen Buche Richtung Säntis](saentis.jpg)
