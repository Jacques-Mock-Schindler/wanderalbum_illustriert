# %% [markdown]
# # Wäggital - Sihlsee

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Innerthal, Staumauer |
# | Ziel | Euthal, Höhport |
# | Strecke | 11.8 km |
# | Aufstieg | 885 m |
# | Abstieg | 895 m |
# | Marschzeit | 4 h 40 |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [47.097662, 8.866374]
cener_swiss_grid = [2708385.71, 1217281.10]
path = "../../../files/2025/250809_waeggital/250809_waeggital.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Wäggital - Sihlsee")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::
# ::: {.content-visible when-format="pdf"}
# ![](../../../images/250809_map_output.png)
# :::
#
# <div style="margin-bottom: 5mm;"></div>

# %%
profile(path)

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](../../../images/250809_elevation_profile.png)
# :::

# %% [markdown]
# [Die Karte auf der Website von swisstopo.ch
# öffnen.](https://map.geo.admin.ch/#/map?lang=de&center=2708385.71,1217281.10&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum_illustriert/main/files/2025/250809_waeggital/250809_waeggital.gpx)

# %%
generate_qr_code_for_url("https://map.geo.admin.ch/#/map?lang=de&center=2708385.71,1217281.10&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum_illustriert/main/files/2025/250809_waeggital/250809_waeggital.gpx")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](../../../images/250807_qr_tag.png){width=3cm height=3cm}
# :::

# %% [markdown]
# ## Bilder

# %% [markdown]
# ![Wäggitalersee von der Staumauer aus gesehen.](../../../images/250809_waeggitalersee.jpg)

# %% [markdown]
# ![Ein Laufsteg im Aufstieg vom Wäggitalersee zur Bärlaui.](../../../images/250809_laufsteg.jpg)

# %% [markdown]
# ![Reizker](../../../images/250809_reizker.jpg)

# %% [markdown]
# ![Fliegenpilz](../../../images/250809_fliegenpilz.jpg)

# %% [markdown]
# ![Kleine Fliegenpilze](../../../images/250809_kleine_fliegenpilze.jpg)

# %% [markdown]
# ![Goldgelbe Koralle (Bauchweh-Koralle)](../../../images/250809_koralle.jpg)

# %% [markdown]
# ![Der Habichtspilz mit seiner typisch geschuppten Hutoberfläche.](../../../images/250809_habichtspilz.jpg)

# %% [markdown]
# ![Alp Bärlaui](../../../images/250809_baerlaui.jpg)

# %% [markdown]
# ![Ein Bergahorn auf der Alp Bärlaui](../../../images/250809_bergahorn.jpg)

# %% [markdown]
# ![Aussicht vom Brünnelistock bis zum Mutteristock](../../../images/250809_aussicht_baerlaui.jpg)

# %% [markdown]
# ![Der Fluebrig(?)](../../../images/250809_fluebrig.jpg)

# %% [markdown]
# ![Silberdisteln](../../../images/250809_silberdisteln.jpg)

# %% [markdown]
# ![Ein Parasol mit seinem typisch genatterten Stiel und noch geschlossenem Hut.](../../../images/250809_kleiner_parasol.jpg)

# %% [markdown]
# ![Feuchtgebiet am Nüssen](../../../images/250809_nuessen.jpg)

# %% [markdown]
# ![Wegmarke oder Gesicht?](../../../images/250809_wegmarke.jpg)
