# %% [markdown]
# # Vounetse

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Charmey (Gruyères) |
# | Ziel | Charmey (Gruyères) |
# | Strecke | 9.7 km |
# | Aufstieg | 790 m |
# | Abstieg | 790 m |
# | Marschzeit | 3 h 55 |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [46.622577, 7.188754]
cener_swiss_grid = [2580860.94, 1163511.39]
path = "250528_vounetse.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Vounetse")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](../../../images/250528_map_output.png)
# :::

# %%
profile(path)

# %% [markdown]
# Die Karte auf der Website von
# [swisstopo.ch](https://map.geo.admin.ch/#/map?lang=de&center=2580860.94,1163511.39&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum_illustriert/refs/heads/main/files/2025/250528_vounetse/250528_vounetse.gpx)
# oder in der
# [Mobile App](https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvcmVmcy9oZWFkcy9tYWluL2ZpbGVzLzIwMjUvMjUwNTI4X3ZvdW5ldHNlLzI1MDUyOF92b3VuZXRzZS5ncHg=)
# von swisstopo öffnen.

# %%
generate_qr_code_for_url("https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvcmVmcy9oZWFkcy9tYWluL2ZpbGVzLzIwMjUvMjUwNTI4X3ZvdW5ldHNlLzI1MDUyOF92b3VuZXRzZS5ncHg=")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# | Swisstopo.ch | Mobile App |
# | --- | --- |
# | ![](../../../images/250528_qr_tag.png){width=3cm height=3cm} | ![](../../../images/250528_app_qr_tag.png){width=3cm height=3cm} |
# :::

# %% [markdown]
# ::: {.content-visible when-format="html"}
#
# ## Bilder

# %% [markdown]
# ![Le Moléson von oberhalb von Charmey aus gesehen.](../../../images/250528_moleson.jpg)

# %% [markdown]
# ![ohne Worte](../../../images/250528_knotenbaum.jpg)

# %% [markdown]
# ![ohne Worte](../../../images/250528_gabelbaum.jpg)

# %% [markdown]
# ![Dent du Bourgo, Dent du Chamois, Dent de Broc und Moléson (v.l.n.r.).](../../../images/250528_dents.jpg)

# %% [markdown]
# ![Das Restaurant an der Bergstation Vounetse. Man beachte die Fahne.](../../../images/250528_restaurant.jpg)

# %% [markdown]
# ![Ein Weissdorn in voller Blüte.](../../../images/250528_weissdorn.jpg)

# %% [markdown]
# ![Ankebälli (Europäische Trollblume).](../../../images/250528_trollblume.jpg)

# %% [markdown]
# ![Moos-Nabelmiere.](../../../images/250528_nabelmiere.jpg)

# %% [markdown]
# :::
