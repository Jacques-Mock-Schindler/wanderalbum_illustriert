# %% [markdown]
# # Wanderung über den Fläscherberg

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Fläsch, Dorf |
# | Ziel | Maienfeld |
# | Strecke | 15.4 km |
# | Aufstieg | 725 m |
# | Abstieg | 740 m |
# | Marschzeit | 4 h 35 |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [47.032270, 9.518935]
cener_swiss_grid = [2758107.18, 1211121.43]
path = "251019_flaesch.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Fläscherberg")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::
# ::: {.content-visible when-format="pdf"}
# ![](../../../images/251019_map_output.png)
# :::
#
# <div style="margin-bottom: 5mm;"></div>

# %%
profile(path)

# %% [markdown]
# Die Karte auf der Website von
# [swisstopo.ch](https://map.geo.admin.ch/#/map?lang=de&center=2758107.18,1211121.43&z=6&topic=ech&layers=GPX%7Chttps://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum_illustriert/main/files/2025/251019_flaesch/251019_flaesch.gpx;ch.vbs.schiessanzeigen&bgLayer=ch.swisstopo.pixelkarte-farbe)
# oder in der
# [Mobile App](https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvbWFpbi9maWxlcy8yMDI1LzI1MTAxOV9mbGFlc2NoLzI1MTAxOV9mbGFlc2NoLmdweA==)
# von swisstopo öffnen.

# %%
generate_qr_code_for_url("https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvbWFpbi9maWxlcy8yMDI1LzI1MTAxOV9mbGFlc2NoLzI1MTAxOV9mbGFlc2NoLmdweA==")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# | Swisstopo.ch | Mobile App |
# | --- | --- |
# | ![](../../../images/251019_qr_tag.png){width=3cm height=3cm} | ![](../../../images/251019_app_qr_tag.png){width=3cm height=3cm} |
# |    | Layer Schiessanzeigen laden! |
#
# :::

# %% [markdown]
# ::: {.content-visible when-format="html"}
# ## Bilder

# %% [markdown]
# ![Weinberg ausgangs Fläsch am Fuss des Schnielskopfs.](../../../images/251019_weinberg.jpg)

# %% [markdown]
# ![Der Gonzen über den Fläscher Weinbergen.](../../../images/251019_gonzen.jpg)

# %% [markdown]
# ![Weinlaub.](../../../images/251019_weinlaub.jpg)

# %% [markdown]
# ![Eine Buche in der Flanke des Fläscherbergs.](../../../images/251019_buche.jpg)

# %% [markdown]
# ![Der Pizalun von der Flanke des Fläscherbegs aus gesehen.](../../../images/251019_pizalun.jpg)

# %% [markdown]
# ![Der Rhein von der Flanke des Fläscherbergs aus geshen.](../../../images/251019_rhein.jpg)

# %% [markdown]
# ![ohne Worte](../../../images/251019_peace.jpg)

# %% [markdown]
# ![Aufstieg in der Flanke des Fläscherbergs.](../../../images/251019_flanke.jpg)

# %% [markdown]
# ![**Die** Flanke des Fläscherbergs.](../../../images/251019_flanke2.jpg)

# %% [markdown]
# ![Ein Stück Rinde.](../../../images/251019_rinde.jpg)

# %% [markdown]
# ![Pilze wie ein Schwarm Schmetterlinge.](../../../images/251019_pilze.jpg)

# %% [markdown]
# ![Im Aufstieg.](../../../images/251019_aufstieg.jpg)

# %% [markdown]
# ![Die Mattheid.](../../../images/251019_mattheid.jpg)

# %% [markdown]
# ![Ein Teich am unteren Rand des Hinter Ochsenbergs.](../../../images/251019_tuempel.jpg)

# %% [markdown]
# ![Das Blockhaus B, Teil der historischen Aussenanlagen der Festung St. Luzisteig.](../../../images/251019_blockhaus_b.jpg)

# %% [markdown]
# ![Abstieg vom Blockhaus E in Richtung Vorder Ochsenberg.](../../../images/251019_abstieg.jpg)

# %% [markdown]
# ![Das Blockhaus Z, Teil dre historischen Aussenanlagen der Festung St. Luzisteig.](../../../images/251019_blockhaus_z.jpg)

# %% [markdown]
# ![Der Eichenhain Bovel oberhalb von Maienfeld.](../../../images/251019_bovel.jpg)

# %% [markdown]
# ![Dorfbrunnen in Maienfeld.](../../../images/251019_dorfbrunnen.jpg)

# %% [markdown]
# :::
