# %% [markdown]
# # Hauterive - Fribourg

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Hauterive |
# | Ziel | Fribourg |
# | Strecke | 11 km |
# | Aufstieg | 300 m |
# | Abstieg | 303 m |
# | Marschzeit | 3 h |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [46.781462, 7.134113]
cener_swiss_grid = [2576744.78, 1181188.78]
path = "../../../files/2025/250807_hautrive/250807_hauterive.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Hauterive - Fribourg")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::
# ::: {.content-visible when-format="pdf"}
# ![](../../../images/250807_map_output.png)
# :::
#
# <div style="margin-bottom: 5mm;"></div>

# %%
profile(path)

# %% [markdown]
# Die Karte auf der Website von
# [swisstopo.ch](https://map.geo.admin.ch/#/map?lang=de&center=2576744.78,1181188.78&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum_illustriert/main/files/2025/250807_hautrive/250807_hauterive.gpx)
# oder in der
# [Mobile App](https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvbWFpbi9maWxlcy8yMDI1LzI1MDgwN19oYXV0cml2ZS8yNTA4MDdfaGF1dGVyaXZlLmdweA==)
# von swisstopo öffnen.

# %%
generate_qr_code_for_url("https://swisstopo.app/u/aHR0cHM6Ly9yYXcuZ2l0aHVidXNlcmNvbnRlbnQuY29tL0phY3F1ZXMtTW9jay1TY2hpbmRsZXIvd2FuZGVyYWxidW1faWxsdXN0cmllcnQvbWFpbi9maWxlcy8yMDI1LzI1MDgwN19oYXV0cml2ZS8yNTA4MDdfaGF1dGVyaXZlLmdweA==")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# | Swisstopo.ch | Mobile App |
# | --- | --- |
# | ![](../../../images/250807_qr_tag.png){width=3cm height=3cm} | ![](../../../images/250807_app_qr_tag.png){width=3cm height=3cm} |
#
# :::

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %% [markdown]
# ## Bilder

# %% [markdown]
# ![Legotempel im Legoladen im Bahnhof von Bulle (nach dem Besuch des Marché und noch vor dem Start der Wanderung)](../../../images/250807_lego.jpg)

# %% [markdown]
# ![Das Kloster Hauterive](../../../images/250807_kloster.jpg)

# %% [markdown]
# ![Ein geschnitzter Zaunpfahl im Zaun, welcher das Gelände des Klosters vom Wanderweg abgrenzt.](../../../images/250807_zaunpfahl1.jpg)

# %% [markdown]
# ![Noch ein Zaunpfahl. Auf eine Länge von ca. 750 m war ungefähr jeder zweite Zaunpfahl mit einem Gesicht versehen.](../../../images/250807_zaunpfahl2.jpg)

# %% [markdown]
# ![Die Sarine vom Pont de l'Hôtel](../../../images/250807_sarine.jpg)

# %% [markdown]
# ![Das Symbol für den Themenweg, aufgenommen kurz vor Marly.](../../../images/250807_themenwegweiser.jpg)

# %% [markdown]
# ![Beim ersten Pfeiler des Pont de Pérolles.](../../../images/250807_schaf.jpg)

# %% [markdown]
# ![Eine Route im Kletterpark an den Pfeilern des Pont de Pérolles.](../../../images/250807_kletterpark.jpg)

# %% [markdown]
# ![Die zum Lac de Prolles gestaute Sarine.](../../../images/250807_lac_de_prolles.jpg)

# %% [markdown]
# :::
