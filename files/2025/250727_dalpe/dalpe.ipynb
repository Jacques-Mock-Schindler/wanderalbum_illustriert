# %% [markdown]
# # Rundwanderung Faido - Dalpe Faido

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Faido |
# | Ziel | Faido |
# | Strecke | 16.8 km |
# | Aufstieg | 880 m |
# | Abstieg | 880 m |
# | Marschzeit | 5 h 30 |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [46.483021, 8.772617]
cener_swiss_grid = [2702430.57, 1148836.93]
path = "../../../files/2025/250727_dalpe/250727_dalpe.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Rundwanderung Faido - Dalpe - Faido")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](map_output.png)
# :::

# %% [markdown]
# <div style="margin-bottom: 5mm;"></div>
#
# ::: {.content-visible when-format="html"}

# %%
profile(path)

# %% [markdown]
# :::
#
# ::: {.content-visible when-format="pdf"}
# ![](elevation_profile.png)
# :::

# %% [markdown]
# [Die Karte auf der Website von swisstopo.ch
# öffnen.](https://map.geo.admin.ch/#/map?lang=de&center=2702430.57,1148836.93&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum/main/files/2025/250727_dalpe/250727_dalpe.gpx)

# %%
generate_qr_code_for_url("https://map.geo.admin.ch/#/map?lang=de&center=2702430.57,1148836.93&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum/main/files/2025/250727_dalpe/250727_dalpe.gpx")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](qr_tag.png){width=3cm height=3cm}
# :::

# %% [markdown]
# ## Bilder

# %% [markdown]
# ![Morbide Kulisse beim Start vis-a-vis vom Bahnhof Faido.](hotel_faido.jpg)

# %% [markdown]
# ![Auch weiter unten im Dorf, Richtung Ticiono gibt es noch Liegenschaften mit Potenzial.](potential.jpg)

# %% [markdown]
# ![Eine etwas aus der Zeit gefallene Reklame für Faido oberhalb des Wasserfalls von Piumogna.](reklame.jpg)

# %% [markdown]
# ![Nicht **der** Wasserfall - aber ein hübscher Zufluss.](wasserfall.jpg)

# %% [markdown]
# ![Ein Kaisermantel(?) auf einer Wiese vor Piana Selva.](kaisermantel.jpg)

# %% [markdown]
# ![Ein Schachbrett auf der gleichen Wiese.](schachbrett.jpg)

# %% [markdown]
# ![Ein verfallender Stall kurz nach Piana Selva.](stall.jpg)

# %% [markdown]
# ![Zwischen der Piana Selva und Dalpe gibt es ein im Wald ein kleines Feuchtgebiet.](feuchtgebiet.jpg)

# %% [markdown]
# ![Die Piumogna kurz vor Dalpe.](piumogna.jpg)

# %% [markdown]
# ![Stein im Moosmantel (kurz vor Dalpe)](stein.jpg)

# %% [markdown]
# ![Der Ticino von der Brücke bei Dazio Grande aus aufgenommen.](ticino_dazio_grande.jpg)

# %% [markdown]
# ![Eisenbahnbrücke Ponte di Mezzo](ponte_di_mezzo.jpg)

# %% [markdown]
# ![Alle wesentlichen Verkehrsträger in der Leventina vom Ponte Vecchio aus aufgenomemen.](verkehrstraeger.jpg)

# %% [markdown]
# ![Steinschlagsicherung bei Ponte](steinschlagsicherung.jpg)
