# %% [markdown]
# # Schweiz Mobil 950: Churfirstenweg

# %% [markdown]
# ## Allgemeine Angaben

# %% [markdown]
# |   |   |
# | --- | --- |
# | Start | Alp Selamatt |
# | Ziel | Gamsalp |
# | Strecke | 10.8 km |
# | Aufstieg | 1'100 m |
# | Abstieg | 750 m |
# | Marschzeit | 4 h 40 |

# %%
import folium
import gpxpy
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt
import qrcode
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import RadialGradiantColorMask
import sys
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
sys.path.append(os.path.abspath("../../../scripts"))
from scripts import *

# %%
center = [46.547401, 9.864038]
cener_swiss_grid = [2785994.27, 1157998.39]
path = "260730_valbever.gpx"

# %% [markdown]
# ::: {.content-visible when-format="html"}

# %%
m = create_map(center, path, "Bever - Spinas - Margunin - Samedan")
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# :::

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# ![](../../../images/2026/260730/260730_map_output.png)
# :::

# %%
profile(path)

# %% [markdown]
# Die Karte auf der Website von
# [swisstopo.ch](https://map.geo.admin.ch/#/map?lang=de&center=2785994.27,1157998.39&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum_illustriert/main/files/2026/260730_valbever/260730_valbever.gpx)
# oder in der
# [Mobile App](https://swisstopo.)
# von swisstopo öffnen.

# %%
generate_qr_code_for_url("https://map.geo.admin.ch/#/map?lang=de&center=2785994.27,1157998.39&z=6&bgLayer=ch.swisstopo.pixelkarte-farbe&topic=ech&layers=GPX|https://raw.githubusercontent.com/Jacques-Mock-Schindler/wanderalbum_illustriert/main/files/2026/260730_valbever/260730_valbever.gpx")

# %% [markdown]
# ::: {.content-visible when-format="pdf"}
# | Swisstopo.ch | Mobile App |
# | --- | --- |
# | ![](../../../images/2026/260730/260730_qr_tag.png){width=3cm height=3cm} | ![](../../../images/2026/260730/260730_app_qr_tag.png){width=3cm height=3cm} |
# :::

# %% [markdown]
# ::: {.content-visible when-format="html"}
#
# ## Bilder

# %% [markdown]
# ![In Natura haben wir zwar keine Otter beobachten können, die
# Holzskulptur am Bahnhof Bever verdient aber trotzdem Aufnahme ins Album.](../../../images/2026/260730/PXL_20260730_070418625.jpg)

# %% [markdown]
# ![Blick entlang des Beverin in Richtung Spinas. Die Steine im
# Vordergrund waren unsere Zmroge-Bänkli.](../../../images/2026/260730/PXL_20260730_073721858.jpg)

# %% [markdown]
# ![Der Weg durch das Val Bever führt am Schiessstand von Bever vorbei.
# Vorsorglicherweise stellen die Schützen in einer Box Gehörschütze bereit.](../../../images/2026/260730/PXL_20260730_081653069.jpg)

# %% [markdown]
# ![Der Weg von Bever nach Spinas ist als Märliweg eingerichtet. Der Stuhl
# für Märchenerzähler...](../../../images/2026/260730/PXL_20260730_084730342.jpg)

# %% [markdown]
# ![...wird tatsächlich genutzt. Vorgelesen wird 'Die erste Pfeife der
# Hexe Ludovica-Goba.](../../../images/2026/260730/PXL_20260730_084837101.jpg)

# %% [markdown]
# ![Der IR 38 von St. Moritz (Samedan ab 11:15 - vier Stunden später sehen
# wir in die andere Richtung) nach Chur im Bahnhof
# Spinas.](../../../images/2026/260730/PXL_20260730_092727843.jpg)

# %% [markdown]
# ![Andi nach der Überquerung eines Bächleins kurz vor der Waldgrenze. Die
# Hälfte des Aufstiegs haben wir da hinter uns.](../../../images/2026/260730/PXL_20260730_095615859.jpg)

# %% [markdown]
# ![Jacques im Bächlein etwas über der Waldgrenze.](../../../images/2026/260730/PXL_20260730_100027705.jpg)

# %% [markdown]
# ![Ein Blauer Eisenhut (Aconitum napellus), die giftigste Pflanze
# Europas. Schön ist die Blume trotzdem.](../../../images/2026/260730/PXL_20260730_100111980.jpg)

# %% [markdown]
# ![Schon fast oben. Dafür, dass sich der Weg bereits weit über 2'000 müM
# befindet, ist es immer noch ordentlich warm.](../../../images/2026/260730/PXL_20260730_102645020.jpg)

# %% [markdown]
# ![Blick zurück Richtung Val Bever auf die Kette von Piz da las Blais -
# Piz Mez - Crasta Mora. Der helle Berg dahinter ist der Piz Üertsch.](../../../images/2026/260730/PXL_20260730_104443197.jpg)

# %% [markdown]
# ![Ein Fransenenzian auf dem Scheitelpunkt der Wanderung.](../../../images/2026/260730/PXL_20260730_104612905.jpg)

# %% [markdown]
# ![Ein Frühlings-Enzian (Gentiana verna).](../../../images/2026/260730/PXL_20260730_104638242.jpg)

# %% [markdown]
# ![Aufgenommen wegen der Gemeindewappen von Samedan und Bever.](../../../images/2026/260730/PXL_20260730_105129350.jpg)

# %% [markdown]
# ![Der Ausblick im Abstieg; Samedan und Pontresina mit der Berninangruppe im
# Hintergrund.](../../../images/2026/260730/PXL_20260730_110229461.jpg)

# %% [markdown]
# ![Eine Blüte des Gemswurz-Greiskrauts (Senecio abrotanifolius).](../../../images/2026/260730/PXL_20260730_110715144.jpg)

# %% [markdown]
# ![Kühe in der Mittagspause. Nein sie sind nicht tot. Aber zu Fressen
# haben sie nicht mehr viel.](../../../images/2026/260730/PXL_20260730_113510496.jpg)

# %% [markdown]
# ![Eine Spinnweb-Hauswurz (Sempervivum arachnoideum).](../../../images/2026/260730/PXL_20260730_121707800.jpg)

# %% [markdown]
# ![ohne Worte](../../../images/2026/260730/PXL_20260730_124342322.jpg)
